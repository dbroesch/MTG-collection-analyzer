# %% [markdown]
# ###

# %%
import json
from pathlib import Path
import pandas as pd
pd.set_option("display.max_rows", None)
from missing_cards import load_collection_csv, get_missing_cards

# %% [markdown]
# ### Calls function to get all missing cards

# %%
cards =get_missing_cards("collection_2_25_26.csv")
# Out:
# [DEBUG] Mirage: set=335 | in_collection=88 | missing=247
# [DEBUG] Visions: set=167 | in_collection=45 | missing=122
# [DEBUG] Weatherlight: set=167 | in_collection=48 | missing=119

# %% [markdown]
# ### Prints out the name of missing cards from a given set in collection

# %%
print(cards[2]["name"].to_csv(index=False))
# Out:
# name
# Abduction
# Abeyance
# Aboroth
# Abyssal Gatekeeper
# Aether Flash
# Agonizing Memories
# Alabaster Dragon
# Angelic Renewal
# Apathy
# Arctic Wolves
# Argivian Find
# Avizoa
# Benalish Infantry
# Benalish Knight
# Blossoming Wreath
# Bogardan Firefiend
# Bone Dancer
# Bösium Strip
# Briar Shield
# Bubble Matrix
# Buried Alive
# Call of the Wild
# Cinder Wall
# Circling Vultures
# Cloud Djinn
# Cone of Flame
# Debt of Loyalty
# Dense Foliage
# Desperate Gambit
# Dingus Staff
# Doomsday
# Downdraft
# Duskrider Falcon
# Dwarven Thaumaturgist
# Ertai's Familiar
# Familiar Ground
# Fatal Blow
# Fervor
# Festering Evil
# Firestorm
# Fire Whip
# Fit of Rage
# Fledgling Djinn
# Flux
# Foriysian Brigade
# Fungus Elemental
# Gaea's Blessing
# Gallowbraid
# Gerrard's Wisdom
# Goblin Bomb
# Goblin Grenadiers
# Goblin Vandal
# Harvest Wurm
# Haunting Misery
# Heart of Bogardan
# Heat Stroke
# Heavy Ballista
# Hurloon Shaman
# Infernal Tribute
# Inner Sanctum
# Jabari's Banner
# ...
